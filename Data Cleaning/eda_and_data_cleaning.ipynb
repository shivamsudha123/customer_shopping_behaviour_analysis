# %% [markdown]
# EDA

# %%
#importing pandas library
import numpy as np
import pandas as pd

# %%
 df = pd.read_csv("C:/Users/Shivam Sudha/Desktop/customer_shopping_behaviour_analysis/data/unclean_data.csv")

# %%
df

# %%
df.head(10)

# %%
df.tail()

# %%
len(df)

# %%
df.shape

# %%
df.describe()

# %%
df.describe (include ="all")

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# Data cleaning

# %%
df['Item Purchased'].unique()

# %%
df['Category'].unique()
# Out:
# <StringArray>
# ['Footwear', 'Clothing', 'Accessories', 'Outerwear']
# Length: 4, dtype: str

# %%
df.groupby('Category')['Item Purchased'].unique()
# Out:
# Category
# Accessories    [Socks, Blouse, Boots, Hat, Scarf, Belt, Coat, Handbag, Shoes, Shorts, Jewelry, Sweater, Sneakers, Pants, T-shirt, Hoodie, Jeans, Jacket, Backpack, Sunglasses, Dress, Skirt, Shirt, Sandals, Gloves]
# Clothing       [Boots, Skirt, Shirt, Belt, Hoodie, Hat, Dress, Coat, Blouse, Pants, Sunglasses, Jeans, Scarf, Jacket, Shorts, Handbag, Gloves, Sneakers, Sweater, T-shirt, Jewelry, Sandals, Socks, Backpack, Shoes]
# Footwear       [Scarf, Sandals, Handbag, Skirt, Socks, Sunglasses, Hat, Jewelry, Gloves, Pants, Coat, Belt, Sweater, Shirt, T-shirt, Boots, Backpack, Shoes, Dress, Blouse, Jacket, Jeans, Sneakers, Shorts, Hoodie]
# Outerwear      [Dress, Shorts, Sneakers, Sandals, Boots, Blouse, Sweater, Jacket, Belt, Coat, Hoodie, T-shirt, Scarf, Hat, Pants, Shirt, Sunglasses, Jewelry, Backpack, Socks, Gloves, Jeans, Skirt, Handbag, Shoes]
# Name: Item Purchased, dtype: object

# %%
pd.set_option('display.max_colwidth',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %% [markdown]
# Fix category and Item purchased column

# %%
corect_mapping = {
    #Clothing 
 
}
